# %%
import pandas as pd 
import indicadores

# %%
df = pd.read_csv("btc_project_train.csv").loc[:, ["Open","Close","High","Low"]]

df.rename(columns={"Open": "open", "Close": "close", "High": "high", "Low": "low"}, inplace=True)

df
# Out:
#                 open         close          high           low
# 0       31803.693359  31834.984375  31834.984375  31803.693359
# 1       31834.910156  31853.056640  31853.056640  31834.910156
# 2       31854.175781  31747.378906  31854.175781  31747.339843
# 3       31750.771484  31840.392578  31840.392578  31750.771484
# 4       31844.460937  31777.644531  31844.460937  31777.644531
# ...              ...           ...           ...           ...
# 166445           NaN           NaN           NaN           NaN
# 166446           NaN           NaN           NaN           NaN
# 166447           NaN           NaN           NaN           NaN
# 166448           NaN           NaN           NaN           NaN
# 166449  42152.097656  42198.000000  42198.000000  42152.097656
#
# [166450 rows x 4 columns]

# %%
ind = indicadores.add_indicators(df)
ind
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ind = indicadores.add_indicators(df)
#       2 ind
#
# File c:\Users\Isabela\Documents\Iteso\9no Semestre\Trading\Act04\indicadores.py:58, in add_indicators(df)
#      56 out["rsi_14"] = rsi(df, 14)
#      57 out = out.join(macd(df, 26, 12, 9))
# ---> 58 out = out.join(stochastic(df, 14, 3))
#      59 return out
#
# File c:\Users\Isabela\Documents\Iteso\9no Semestre\Trading\Act04\indicadores.py:45, in stochastic(df, window, smooth)
#      39 def stochastic(df: pd.DataFrame, window: int = 14, smooth: int = 3):
#      40     st = ta.momentum.StochasticOscillator(
#      41         high=df['high'], low=df['low'], close=df['close'], window=window, smooth_window=smooth
#      42     )
#      43     return pd.DataFrame({
#      44         "stoch_k" : st.stoch(),
# ...
